# %%
# %pip install -q git+https://github.com/huggingface/transformers.git
# %pip install -q tensorflow==2.8
# %pip install transformers
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 74.5 MB/s eta 0:00:00
#   Building wheel for transformers (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.6/497.6 MB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 107.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 kB 41.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 84.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 103.3 MB/s eta 0:00:00
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.30.0.dev0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from transformers import TFGPT2LMHeadModel, GPT2Tokenizer

# %%
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# add the EOS token as PAD token to avoid warnings
model = TFGPT2LMHeadModel.from_pretrained("gpt2", pad_token_id=tokenizer.eos_token_id)
# Out:
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading tf_model.h5:   0%|          | 0.00/498M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFGPT2LMHeadModel.
#
# All the layers of TFGPT2LMHeadModel were initialized from the model checkpoint at gpt2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.
# Downloading (…)neration_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/ANLP/Data/eventwise_csv/NO RUN.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0  Match_id          Team  Over_num  \
# 0            78   7898444   MI 1st Inns      17.3
# 1           310   7200146   GL 1st Inns      13.3
# 2           314   7200146   GL 1st Inns      17.0
# 3           324   7200146   GL 1st Inns       5.0
# 4           335   7200146  SRH 1st Inns      13.3
# ..          ...       ...           ...       ...
# 150       11086   4947883   DC 1st Inns      19.5
# 151       11136   4947883  KKR 1st Inns       6.3
# 152       11157   9843066   MI 1st Inns      18.0
# 153       11297   4491659  RCB 1st Inns       0.2
# 154       11318   4491659  RCB 1st Inns       5.3
#
#                                             Commentary  \
# 0    Dinda to Pollard, no run, was that a drop? Nee...
# 1    Nehra to Dwayne Smith, no run, brilliant work ...
# 2    Bhuvneshwar to Karthik, no run, oh nearly.. A ...
# 3    Rashid Khan to Raina, no run, edged and droppe...
# 4    Nehra to Dwayne Smith, no run, brilliant work ...
# ..                                                 ...
# 150  Russell to Hetmyer, no run, this is excellent ...
# 151  Mishra to Nitish Rana, no run, dropped! It was...
# 152  Sandeep Sharma to Hardik Pandya, no run, a lou...
# 153  Rabada to Finch, no run, Rabada drops it! Such...
# 154  Nortje to de Villiers, no run, a direct-hit at...
#
#                              batsman   score  \
# 0                   Dinda to Pollard  NO RUN
# 1              Nehra to Dwayne Smith  NO RUN
# 2             Bhuvneshwar to Karthik  NO RUN
# 3               Rashid Khan to Raina  NO RUN
# 4              Nehra to Dwayne Smith  NO RUN
# ..                               ...     ...
# 150               Russell to Hetmyer  NO RUN
# 151            Mishra to Nitish Rana  NO RUN
# 152  Sandeep Sharma to Hardik Pandya  NO RUN
# 153                  Rabada to Finch  NO RUN
# 154            Nortje to de Villiers  NO RUN
#
#                                         Commentary_new Team_new  \
# 0    {{BOWLER}} to {{BATSMAN}}, no run, was that a ...       MI
# 1    {{BOWLER}} to {{BATSMAN}}, no run, brilliant w...       GL
# 2    {{BOWLER}} to {{BATSMAN}}, no run, oh nearly.....       GL
# 3    {{BOWLER}} to {{BATSMAN}}, no run, edged and d...       GL
# 4    {{BOWLER}} to {{BATSMAN}}, no run, brilliant w...      SRH
# ..                                                 ...      ...
# 150  {{BOWLER}} to {{BATSMAN}}, no run, this is exc...       DC
# 151  {{BOWLER}} to {{BATSMAN}}, no run, dropped! It...      KKR
# 152  {{BOWLER}} to {{BATSMAN}}, no run, a loud shou...       MI
# 153  {{BOWLER}} to {{BATSMAN}}, no run, {{BOWLER}} ...      RCB
# 154  {{BOWLER}} to {{BATSMAN}}, no run, a direct-hi...      RCB
#
#                  P2             P1    P1_FN     P1_LN        P2_FN   P2_LN  \
# 0             Dinda        Pollard  Pollard       NaN        Dinda     NaN
# 1             Nehra   Dwayne Smith   Dwayne     Smith        Nehra     NaN
# 2       Bhuvneshwar        Karthik  Karthik       NaN  Bhuvneshwar     NaN
# 3       Rashid Khan          Raina    Raina       NaN       Rashid    Khan
# 4             Nehra   Dwayne Smith   Dwayne     Smith        Nehra     NaN
# ..              ...            ...      ...       ...          ...     ...
# 150         Russell        Hetmyer  Hetmyer       NaN      Russell     NaN
# 151          Mishra    Nitish Rana   Nitish      Rana       Mishra     NaN
# 152  Sandeep Sharma  Hardik Pandya   Hardik    Pandya      Sandeep  Sharma
# 153          Rabada          Finch    Finch       NaN       Rabada     NaN
# 154          Nortje    de Villiers       de  Villiers       Nortje     NaN
#
#      P1_FN_count  P1_LN_count  P2_FN_count  P2_LN_count
# 0              7          NaN            5          NaN
# 1              6          5.0            5          NaN
# 2              7          NaN           11          NaN
# 3              5          NaN            6          4.0
# 4              6          5.0            5          NaN
# ..           ...          ...          ...          ...
# 150            7          NaN            7          NaN
# 151            6          4.0            6          NaN
# 152            6          6.0            7          6.0
# 153            5          NaN            6          NaN
# 154            2          8.0            6          NaN
#
# [155 rows x 19 columns]>

# %%
import os
os.makedirs("./input", exist_ok = False)

# %%
os.makedirs("./output", exist_ok = False)

# %%
len(df)
# Out:
# 155

# %%
for i in range(len(df)):
    commentary = df.Commentary_new[i]               # This is the text of row 'i'.
    f = open("./input/" + str(i) + ".txt", "w")   # This writes a new text file.
    f.write(commentary)                             
    f.close()

# %%
mypath = './input/'
import os
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
print(onlyfiles)
corpus = ''
for i in range(len(onlyfiles)):
  if onlyfiles[i][-3:] == 'txt':
    try:
      with open(mypath+ onlyfiles[i], 'r') as file:
        data = file.read()
      corpus = corpus + '\n' + data
    except:
      pass
# Out:
# ['41.txt', '28.txt', '60.txt', '125.txt', '57.txt', '111.txt', '146.txt', '34.txt', '72.txt', '107.txt', '137.txt', '102.txt', '32.txt', '153.txt', '12.txt', '73.txt', '154.txt', '58.txt', '147.txt', '8.txt', '3.txt', '119.txt', '25.txt', '92.txt', '82.txt', '99.txt', '141.txt', '112.txt', '54.txt', '59.txt', '124.txt', '89.txt', '39.txt', '105.txt', '140.txt', '70.txt', '1.txt', '144.txt', '114.txt', '18.txt', '116.txt', '47.txt', '69.txt', '152.txt', '138.txt', '27.txt', '121.txt', '52.txt', '29.txt', '67.txt', '21.txt', '135.txt', '90.txt', '96.txt', '30.txt', '130.txt', '23.txt', '110.txt', '38.txt', '22.txt', '0.txt', '48.txt', '117.txt', '108.txt', '127.txt', '122.txt', '14.txt', '7.txt', '77.txt', '46.txt', '35.txt', '88.txt', '4.txt', '74.txt', '45.txt', '133.txt', '6.txt', '136.txt', '33.txt', '65.txt', '10.txt', '31.txt', '83.txt', '78.txt', '128.txt', '149.txt', '26.txt', '43.txt', '87.txt', '93.txt', '143.txt', '139.txt', '36.txt', '42.txt', '68.txt', '148.txt', '17.txt', '79.txt', '76.txt', '5.txt', '115.txt', '40.txt', '24.txt', '37.txt', '84.txt', '61.txt', '123.txt', '118.txt', '71.txt', '97.txt', '81.txt', '20.txt', '95.txt', '94.txt', '98.txt', '15.txt', '62.txt', '100.txt', '120.txt', '55.txt', '50.txt', '134.txt', '109.txt', '142.txt', '101.txt', '80.txt', '150.txt', '113.txt', '16.txt', '44.txt', '131.txt', '85.txt', '151.txt', '104.txt', '56.txt', '106.txt', '19.txt', '91.txt', '126.txt', '13.txt', '75.txt', '66.txt', '86.txt', '53.txt', '51.txt', '129.txt', '132.txt', '63.txt', '64.txt', '9.txt', '2.txt', '103.txt', '49.txt', '145.txt', '11.txt']

# %%
print(corpus)
# Out:
# {{BOWLER}} to {{BATSMAN}}, no run, Punjab have gone for a review. {{BATSMAN}} is a long way down the ground. Ultra edge shows no edge and DRS shows ball is just hitting the leg stump. Punjab retains the review again. {{BATSMAN}} comes down the track on the ball and misses the bat totally, ball hits his pads
# {{BOWLER}} to {{BATSMAN}}, no run, a review for LBW. Looks high to the naked eye but gee that's hit {{BATSMAN}} on the back pad, above the knee roll. Carrom ball I think, which skids on instead of turning away. Beats the batsman for pace and goes through {{BATSMAN}}, who's standing on his back foot to meet that. Ball-tracking is in and it's umpire's call on height, as suspected
# {{BOWLER}} to {{BATSMAN}}, no run, chance and dropped, that's a dolly and Markande has somehow dropped it. Then slower short ball outside off, {{BATSMAN}} swivelled across on the pull, doesn't get hold of the shot and hit it straight to mid-on. It came at a very good height, Markande went reverse cupped and somehow let the ball pop out
# {{BOWLER}} to {{BATSMAN}}, no run, {{BATSMAN}} went for an across the line shot, and he was hit on the pads. He just managed to get an inside edge to it and that saved him there. An excellent over from {{BOWLER}}
# {{BOWLER}} to {{BATSMAN}}, no run, direct-hit and Nair would've been on his way back to the hut. Patel gets an inside edge onto his pad, the ball drops into the off-side. {{BOWLER}} rushes forward, collects the ball and sees Nair stuttering at the middle of the pitch. Picks up and rifles a throw at the non-striker's end, but misses the target
# {{BOWLER}} to {{BATSMAN}}, no run, the inside edge saved the southpaw. Length delivery angling in, {{BATSMAN}} hopped back to defend and missed it. But there was an inside edge and that helped him overturn the umpire's decision which was out
# {{BOWLER}} to {{BATSMAN}}, no run, chance and Rohit has dropped it - fair to say, he has saved four runs - short and just outside off, {{BATSMAN}} rocked back and drilled the pull, to the left of mid-wicket. Rohit moved across quickly, got both hands on the ball, but can't hold on
# {{BOWLER}} to {{BATSMAN}}, no run, now then, there's a review from KKR for leg-before. {{BATSMAN}} didn't pick a googly from {{BOWLER}} and was hit on the back pad. But in real time, it looked like the impact may have been outside off. Oh wait, there's an inside edge too. So that's that
# {{BOWLER}} to {{BATSMAN}}, no run, {{BATSMAN}} has been given out LBW and he immediately reviews. I think it's pitching well outside leg, a shocker from umpire Nandan and feel this will be overturned. No bat on that and it's confirmed by Ultraedge. Hawk-Eye will confirm my doubt and it has pitched miles outside leg. NOT OUT is the call. Poor decision from umpire Nandan and the crowd cheer as NOT OUT flashes on the screen. {{BATSMAN}} was looking to whip a full ball on his pads and missed
# {{BOWLER}} to {{BATSMAN}}, no run, Very fancy shot to attempt off someone like {{BOWLER}} who fizzes the ball through. But the impact is probably just outside off which has saved him. SRH aren't convinced with the umpire's call, so they go for a review. Only to waste it. Flat leg-break just outside off, {{BATSMAN}} wanted to scoop it over the keeper's head, but wasn't able to connect
# {{BOWLER}} to {{BATSMAN}}, no run, that was full, wide, {{BATSMAN}} threw his bat it and misses. There was a noise, MS went for the DRS but there was nothing on the UltraEdge. Mo continues..
# {{BOWLER}} to {{BATSMAN}}, no run, dropped! The penalty you pay for fielding a part-time wicket-keeper. The flatter knuckle ball around off, {{BATSMAN}} moved away to the leg-side and tried to force it off the back foot, the outside edge goes straight in and straight out of Uthappa's gloves. That would have been two set batsmen removed in one over
# {{BOWLER}} to {{BATSMAN}}, no run, uh oh! A bad mix-up there with {{BATSMAN}} being sent back from the middle of the pitch. But he makes it home. The throw isn't a great one from Pathan either. Rana called him initially but then backtracked as {{BATSMAN}} steered it to point. These are nervy times
# {{BOWLER}} to {{BATSMAN}}, no run, interesting stuff. SRH have gone for the review for LBW. Leg-break straightening and the sweep takes the glove on it's way! The appeal was for an LBW, but there was glove on it. It actually came off the glove, but the keeper has dropped it.
# {{BOWLER}} to {{BATSMAN}}, no run, {{BOWLER}} is excited but that looks high. Traps {{BATSMAN}} on the shuffle with this delivery. Oh they've gone for the review. It's hit the knee-roll bang in front of off-stump, so the impact is alright. But as we doubted, the bounce in this Jaipur deck is taking the ball over the stumps -- the ball-tracking confirms. So not out it'll be and Mumbai lose their review
# {{BOWLER}} to {{BATSMAN}}, no run, {{BOWLER}} is jumping for an lbw appeal. Does not get it and Gambhir takes it. To the naked eye, looked like an under edge. Need UltraEdge to confirm. No bat. So we move on. Impact? Outside the line and that is such a poor review and DD burn their only review. Was very full to be sweeping, {{BATSMAN}} went for it and managed to get himself outside the line
# {{BOWLER}} to {{BATSMAN}}, no run, this is a very wide short ball, {{BATSMAN}} tried to fetch the pull shot, missed, the ball sneaked under the under edge, Karthik was confident in his appeal, given out and {{BATSMAN}} overturned the call by reviewing
# {{BOWLER}} to {{BATSMAN}}, no run, brilliant work from Henriques. A direct-hit would've been interesting. A fuller length delivery on the stumps, {{BATSMAN}} pushes it meekly towards extra cover, Moises dives to his right and throws at the non-striker, all in one motion. DK was backing up for a single and had to turn back and dive full-length to make his ground
# {{BOWLER}} to {{BATSMAN}}, no run, and this call, if upheld, could seal the game. Faf given out LBW to a googly from {{BOWLER}}. He's gone for the review. This is shady, as the ball seems to be a bit leg-sidish. You can see middle and off stump when it hit the pad. Williamson has already got his fielders in position, so he doesn't seem very confident. Yes, as expected, it's missing leg stump. Faf survives. {{TEAM}} still alive, if only just
# {{BOWLER}} to {{BATSMAN}}, no run, Saha completed the catch and went up immediately. {{BOWLER}} joined him as well. Williamson trusting his players challenged the decision, but it remains with the onfield call. {{BATSMAN}} steps out and is tucked by the drifter, misses the nudge into the on-side and the ball lobs off the pad to the left of Saha. He moves across to catch that
# {{BOWLER}} to {{BATSMAN}}, no run, excellent use of technology and {{BATSMAN}} survives! Height was the factor that could have saved him but in the end, inside edge does. Was a lovely nipbacker from {{BOWLER}} that pinged {{BATSMAN}} on the back pad. Didn't look dead plumb but the umpire was impressed and raised his finger. After a chat with Guptill, {{BATSMAN}} opted for the DRS and it has saved him in the end
# {{BOWLER}} to {{BATSMAN}}, no run, fullish just outside off, {{BATSMAN}} sits low outside off looking to scoop it over short fine leg. Loses his balance and it flies off the pad to short third man. DK calls for it and grabs. Appeals and the finger went up. {{BATSMAN}} knew he didn't hit it, so got it overturned
# {{BOWLER}} to {{BATSMAN}}, no run, hit straight back at {{BOWLER}} who puts it down. Half a chance here. {{BATSMAN}} had timed that beautifully and the ball was travelling. But it came at a nice height in the followthrough. {{BOWLER}} parries it towards mid-off

# %%
import logging
import os
import pickle
import random
import torch
import torch.nn as nn
import transformers
from torch.utils.data import DataLoader, Dataset, RandomSampler, SequentialSampler
from transformers import (
    GPT2Config,
    GPT2LMHeadModel,
    GPT2PreTrainedModel,
    GPT2Tokenizer,
    PreTrainedModel,
    PreTrainedTokenizer,
)

MODEL_CLASSES = {"gpt2": (GPT2Config, GPT2LMHeadModel, GPT2Tokenizer)}

logger = logging.getLogger(__name__)

# %%
import string
corpus_cleaned = ''.join(filter(lambda x: x in string.printable, corpus))

# %%
class SportCommentaryData(Dataset):
    def __init__(
        self,
        tokenizer: PreTrainedTokenizer,
        #file_path: str,
        block_size=512,
        overwrite_cache=False,
    ):
        #assert os.path.isfile(file_path)

        block_size = block_size - (
            tokenizer.model_max_length - tokenizer.max_len_single_sentence
        )

        # change if args are added at later point
        cached_features_file = os.path.join(
           "gpt2" + "_" + str(block_size) + "_file.txt" 
        )

        if os.path.exists(cached_features_file) and not overwrite_cache:
            logger.info(
                f"Loading features from your cached file {cached_features_file}"
            )
            with open(cached_features_file, "rb") as cache:
                self.examples = pickle.load(cache)
                logger.debug("Loaded examples from cache")
        else:
            logger.info(f"Creating features from file")

            self.examples = []

            text = corpus
            tokenized_text = tokenizer.convert_tokens_to_ids(tokenizer.tokenize(text))

            for i in range(0, len(tokenized_text) - block_size + 1, block_size):
                self.examples.append(
                    tokenizer.build_inputs_with_special_tokens(
                        tokenized_text[i : i + block_size]
                    )
                )

            logger.info(f"Saving features into cached file {cached_features_file}")
            with open(cached_features_file, "wb") as cache:
                
                pickle.dump(self.examples, cache, protocol=pickle.HIGHEST_PROTOCOL)

    def __len__(self):
        return len(self.examples)

    def __getitem__(self, item):
        return torch.tensor(self.examples[item], dtype=torch.long)

# %%
device = 'cpu'
if torch.cuda.is_available():
    device = 'cuda'
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')
model = model.to(device)

dataset = SportCommentaryData(tokenizer= tokenizer )
commentary_loader = DataLoader(dataset,batch_size=1,shuffle=True)

BATCH_SIZE = 1
EPOCHS = 1
LEARNING_RATE = 0.0002
WARMUP_STEPS = 2000

from transformers import AdamW, get_linear_schedule_with_warmup

model = model.to(device)
model.train()
optimizer = AdamW(model.parameters(), lr=LEARNING_RATE)
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=WARMUP_STEPS, num_training_steps=-1)
script_count = 0
sum_loss = 0.0
batch_count = 0

for epoch in range(EPOCHS):
    print(f"EPOCH {epoch} started" + '=' * 30)
    for idx,script in enumerate(commentary_loader):
        outputs = model(script.to(device), labels=script.to(device))
        loss, logits = outputs[:2]                        
        loss.backward()
        sum_loss = sum_loss + loss.detach().data
                       
        script_count = script_count + 1
        if script_count == BATCH_SIZE:
            script_count = 0    
            batch_count += 1
            optimizer.step()
            scheduler.step() 
            optimizer.zero_grad()
            model.zero_grad()
            
        if batch_count == 100:
            model.eval()
            print(f"sum loss {sum_loss}")
            sample_outputs = model.generate(
                                    bos_token_id=random.randint(1,30000),
                                    do_sample=True,   
                                    top_k=50, 
                                    max_length = 1000,
                                    top_p=0.95, 
                                    num_return_sequences=1
                                )

            print("Output:\n" + 100 * '-')
            for i, sample_output in enumerate(sample_outputs):
                  print("{}: {}".format(i, tokenizer.decode(sample_output, skip_special_tokens=True)))
            
            batch_count = 0
            sum_loss = 0.0
            model.train()
output_dir = '/content/drive/MyDrive/ANLP/Model/Model_NoRun'

from transformers import WEIGHTS_NAME, CONFIG_NAME
output_model_file = os.path.join(output_dir, WEIGHTS_NAME)
output_config_file = os.path.join(output_dir, CONFIG_NAME)

torch.save(model.state_dict(), output_model_file)
model.config.to_json_file(output_config_file)
tokenizer.save_vocabulary(output_dir)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/548M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# EPOCH 0 started==============================
# ('/content/drive/MyDrive/ANLP/Model/Model_NoRun/vocab.json',
#  '/content/drive/MyDrive/ANLP/Model/Model_NoRun/merges.txt')

# %%
output_dir = '/content/drive/MyDrive/ANLP/Model/Model_NoRun'
model = GPT2LMHeadModel.from_pretrained(output_dir)
tokenizer = GPT2Tokenizer.from_pretrained(output_dir)

input_ids = tokenizer.encode('Its no run', return_tensors='pt')

sample_outputs = model.generate(
                        input_ids= input_ids,
                        do_sample = True,
                        #num_beams= 5,
                        max_length = 100,
                        top_k = 50,
                        top_p=0.85, 
                        num_return_sequences=1
                    )

print("Output:\n" + 100 * '-')
for i, sample_output in enumerate(sample_outputs):
      print("{}: {}".format(i, tokenizer.decode(sample_output, skip_special_tokens=True)))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Output:
# ----------------------------------------------------------------------------------------------------
# 0: Its no run of the mill event for a lot of people.coliseum.org
#
# "When you're a young guy, you can get a little bit nervous, and you're a little bit uncomfortable. We've got a lot of good young guys coming out, a lot of people getting into these groups that want to get into the arena and do it. We're kind of a group of guys who don't have any real goals to be successful in," said Mike DiNovo,

# %% [markdown]
# ## **Ignored due to less input data and in accurate output model.**

# %%
from nltk.translate.bleu_score import sentence_bleu
reference = "Sam Curran to Dhoni, wide, fuller and slipped down leg-side. MS allows the ball to go through to the keeper. Ashwin has reviewed this. Was it a nick down the leg-side? It was wided and Ashwin out of the blue decided to review. Nothing of the UltraEdge and it stays as a wide. That was bizarre"
genererated = "Its a wide ball to deep mid-wicket, Karthik gets down low and pulls it wide of long-off. Just in front of square, and the man running past was the fielder in the deep S Kaul to Ishan Kishan, FOUR, massive, too full and too straight, Kishan goes after it with a lofted pull through the line, the timing was in sync with the delivery and it raced away through the lineIsh Sodhi"
reference_texts = tokenizer.encode(reference, return_tensors='pt')
generated_texts = tokenizer.encode(genererated, return_tensors='pt')

# Compute BLEU score for each generated text
bleu_scores = []
for ref, gen in zip(reference_texts, generated_texts):
    bleu = sentence_bleu([ref], gen)
    bleu_scores.append(bleu)

# Calculate average BLEU score
avg_bleu = sum(bleu_scores) / len(bleu_scores)
print("Average BLEU score:", avg_bleu)
# Out:
# Average BLEU score: 0.0
