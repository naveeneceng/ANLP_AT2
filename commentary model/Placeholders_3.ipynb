# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_url = '/content/drive/My Drive/Colab Notebooks/AT2B/commentary.csv'
df = pd.read_csv(file_url)

# %%
df_cleaned = df.copy()

# %%
df_cleaned['Commentary_new'] = np.nan
df_cleaned['Team_new'] = df_cleaned['Team'].str.split(' ').str[0]
df_cleaned[['P1', 'P2']] = df_cleaned.batsman.str.split(" to ", expand = True)
df_cleaned[['P1_FN', 'P1_LN']] = df_cleaned['P1'].str.split(" ", 1, expand = True)
df_cleaned[['P2_FN', 'P2_LN']] = df_cleaned['P2'].str.split(" ", 1, expand = True)
# Out:
# <ipython-input-141-f624131bb37e>:4: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df_cleaned[['P1_FN', 'P1_LN']] = df_cleaned['P1'].str.split(" ", 1, expand = True)
# <ipython-input-141-f624131bb37e>:5: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df_cleaned[['P2_FN', 'P2_LN']] = df_cleaned['P2'].str.split(" ", 1, expand = True)

# %%
df_cleaned.sample(5)
# Out:
#       Match_id           Team  Over_num  \
# 899    7374716    MI 1st Inns      18.1
# 2324   2608816    GL 1st Inns      19.1
# 8426   4765480   RCB 1st Inns      11.0
# 5146   2353730    DC 1st Inns       3.2
# 5253   3529537  KXIP 1st Inns      10.5
#
#                                              Commentary  \
# 899   Andrew Tye to Pollard, out Caught by Jadeja!! ...
# 2324  Corey Anderson to Faulkner, out Caught by (sub...
# 8426  Ashwin to Kohli, 1 run, fifty for Kohli! A dif...
# 5146  Gowtham to Prithvi Shaw, FOUR, little backing ...
# 5253  Duminy to Gayle, FOUR, similar delivery but th...
#
#                          batsman score  Commentary_new Team_new  \
# 899        Andrew Tye to Pollard   OUT             NaN       MI
# 2324  Corey Anderson to Faulkner   OUT             NaN       GL
# 8426             Ashwin to Kohli   ONE             NaN      RCB
# 5146     Gowtham to Prithvi Shaw  FOUR             NaN       DC
# 5253             Duminy to Gayle  FOUR             NaN     KXIP
#
#                   P1            P2    P1_FN     P1_LN     P2_FN P2_LN
# 899       Andrew Tye       Pollard   Andrew       Tye   Pollard  None
# 2324  Corey Anderson      Faulkner    Corey  Anderson  Faulkner  None
# 8426          Ashwin         Kohli   Ashwin      None     Kohli  None
# 5146         Gowtham  Prithvi Shaw  Gowtham      None   Prithvi  Shaw
# 5253          Duminy         Gayle   Duminy      None     Gayle  None

# %%
for ind in df_cleaned.index:
  df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary'][ind].replace(df_cleaned['P1'][ind], '{{BATSMAN}}')
  df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary_new'][ind].replace(df_cleaned['P1_FN'][ind], '{{BATSMAN}}')
  if (df_cleaned['P1_LN'][ind] != None) :
    df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary_new'][ind].replace(df_cleaned['P1_LN'][ind], '{{BATSMAN}}')
  df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary_new'][ind].replace(df_cleaned['P2'][ind], '{{BOWLER}}')
  df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary_new'][ind].replace(df_cleaned['P2_FN'][ind], '{{BOWLER}}')
  if (df_cleaned['P2_LN'][ind] != None) :
    df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary_new'][ind].replace(df_cleaned['P2_LN'][ind], '{{BOWLER}}')
  df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary_new'][ind].replace(df_cleaned['Team_new'][ind], '{{TEAM}}')
# Out:
# <ipython-input-143-ca2b51d8a024>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary'][ind].replace(df_cleaned['P1'][ind], '{{BATSMAN}}')

# %%
df_cleaned.sample(5)
# Out:
#       Match_id          Team  Over_num  \
# 8776   7621139  KKR 1st Inns      11.0
# 6954   5789423   DC 1st Inns      18.5
# 5686   5886474   MI 1st Inns      19.3
# 2898   6270193  RPS 1st Inns      20.0
# 7248   9987700  RCB 1st Inns       3.4
#
#                                              Commentary  \
# 8776  Chahal to Uthappa, no run, run-out chance miss...
# 6954  Rasikh Salam to Pant, SIX, going, going and go...
# 5686  Chawla to Cutting, FOUR, now a four. Another f...
# 2898  Pat Cummins to Manoj Tiwary, out Bowled!! That...
# 7248  Bumrah to Kohli, FOUR, oh this could so easily...
#
#                           batsman   score  \
# 8776            Chahal to Uthappa  NO RUN
# 6954         Rasikh Salam to Pant     SIX
# 5686            Chawla to Cutting    FOUR
# 2898  Pat Cummins to Manoj Tiwary     OUT
# 7248              Bumrah to Kohli    FOUR
#
#                                          Commentary_new Team_new  \
# 8776  {{BATSMAN}} to {{BOWLER}}, no run, run-out cha...      KKR
# 6954  {{BATSMAN}} to {{BOWLER}}, SIX, going, going a...       DC
# 5686  {{BATSMAN}} to {{BOWLER}}, FOUR, now a four. A...       MI
# 2898  {{BATSMAN}} to {{BOWLER}}, out Bowled!! That's...      RPS
# 7248  {{BATSMAN}} to {{BOWLER}}, FOUR, oh this could...      RCB
#
#                 P1            P2   P1_FN    P1_LN    P2_FN   P2_LN
# 8776        Chahal       Uthappa  Chahal     None  Uthappa    None
# 6954  Rasikh Salam          Pant  Rasikh    Salam     Pant    None
# 5686        Chawla       Cutting  Chawla     None  Cutting    None
# 2898   Pat Cummins  Manoj Tiwary     Pat  Cummins    Manoj  Tiwary
# 7248        Bumrah         Kohli  Bumrah     None    Kohli    None

# %%
df_cleaned['P1_FN_count'] = df_cleaned['P1_FN'].str.len()
df_cleaned['P1_LN_count'] = df_cleaned['P1_LN'].str.len()
df_cleaned['P2_FN_count'] = df_cleaned['P2_FN'].str.len()
df_cleaned['P2_LN_count'] = df_cleaned['P2_LN'].str.len()

# %%
df_cleaned.sample(5)
# Out:
#       Match_id           Team  Over_num  \
# 6382   9498235   RCB 1st Inns      19.1
# 4675   4793375   CSK 1st Inns       4.2
# 378    9873957   KKR 1st Inns       4.4
# 9107   7436247    DC 1st Inns       7.3
# 6578   9283980  KXIP 1st Inns      13.2
#
#                                              Commentary  \
# 6382  Unadkat to Siraj, FOUR, reverse paddle and get...
# 4675  Siraj to Rayudu, FOUR, short and pulled away. ...
# 378   Krunal Pandya to Uthappa, FOUR, this was quite...
# 9107  Shreyas Gopal to Dhawan, out Stumped!! Gopal's...
# 6578  Jadeja to Nair, SIX, just clears the man in th...
#
#                        batsman score  \
# 6382          Unadkat to Siraj  FOUR
# 4675           Siraj to Rayudu  FOUR
# 378   Krunal Pandya to Uthappa  FOUR
# 9107   Shreyas Gopal to Dhawan   OUT
# 6578            Jadeja to Nair   SIX
#
#                                          Commentary_new Team_new  \
# 6382  {{BATSMAN}} to {{BOWLER}}, FOUR, reverse paddl...      RCB
# 4675  {{BATSMAN}} to {{BOWLER}}, FOUR, short and pul...      CSK
# 378   {{BATSMAN}} to {{BOWLER}}, FOUR, this was quit...      KKR
# 9107  {{BATSMAN}} to {{BOWLER}}, out Stumped!! {{BAT...       DC
# 6578  {{BATSMAN}} to {{BOWLER}}, SIX, just clears th...     KXIP
#
#                  P1       P2    P1_FN   P1_LN    P2_FN P2_LN  P1_FN_count  \
# 6382        Unadkat    Siraj  Unadkat    None    Siraj  None            7
# 4675          Siraj   Rayudu    Siraj    None   Rayudu  None            5
# 378   Krunal Pandya  Uthappa   Krunal  Pandya  Uthappa  None            6
# 9107  Shreyas Gopal   Dhawan  Shreyas   Gopal   Dhawan  None            7
# 6578         Jadeja     Nair   Jadeja    None     Nair  None            6
#
#       P1_LN_count  P2_FN_count  P2_LN_count
# 6382          NaN            5          NaN
# 4675          NaN            6          NaN
# 378           6.0            7          NaN
# 9107          5.0            6          NaN
# 6578          NaN            4          NaN

# %%
df_cleaned.dtypes
# Out:
# Match_id            int64
# Team               object
# Over_num          float64
# Commentary         object
# batsman            object
# score              object
# Commentary_new     object
# Team_new           object
# P1                 object
# P2                 object
# P1_FN              object
# P1_LN              object
# P2_FN              object
# P2_LN              object
# P1_FN_count         int64
# P1_LN_count       float64
# P2_FN_count         int64
# P2_LN_count       float64
# dtype: object

# %%
df_cleaned.shape
# Out:
# (11574, 18)

# %%
count_1 = 0
count_2 = 0
count_3 = 0
count_4 = 0

for ind in df_cleaned.index:
  if df_cleaned['P1_FN_count'][ind] == 1 :
    count_1 = count_1 + 1
  if df_cleaned['P1_LN_count'][ind] == 1 :
    count_2 = count_2 + 1
  if df_cleaned['P2_FN_count'][ind] == 1 :
    count_3 = count_3 + 1
  if df_cleaned['P2_LN_count'][ind] == 1 :
    count_4 = count_4 + 1
print(count_1, count_2, count_3, count_4)
# Out:
# 896 0 448 0

# %%
df_cleaned.drop(df_cleaned[(df_cleaned['P1_FN_count'])==1].index, inplace=True)
df_cleaned.drop(df_cleaned[(df_cleaned['P2_FN_count'])==1].index, inplace=True)

# %%
df_cleaned.shape
# Out:
# (10250, 18)

# %%
count_1 = 0
count_2 = 0
count_3 = 0
count_4 = 0

for ind in df_cleaned.index:
  if df_cleaned['P1_FN_count'][ind] == 1 :
    count_1 = count_1 + 1
  if df_cleaned['P1_LN_count'][ind] == 1 :
    count_2 = count_2 + 1
  if df_cleaned['P2_FN_count'][ind] == 1 :
    count_3 = count_3 + 1
  if df_cleaned['P2_LN_count'][ind] == 1 :
    count_4 = count_4 + 1
print(count_1, count_2, count_3, count_4)
# Out:
# 0 0 0 0

# %%
df_cleaned.sample(5)
# Out:
#       Match_id          Team  Over_num  \
# 1851   8703679  SRH 1st Inns       9.4
# 2089   4078176  RCB 1st Inns       5.5
# 7742   7416638   MI 1st Inns       8.3
# 8593   8556956  RCB 1st Inns       0.3
# 5288   3529537   MI 1st Inns      12.0
#
#                                              Commentary  \
# 1851  Maxwell to Dhawan, FOUR, poor line from Maxwel...
# 2089  McClenaghan to de Villiers, SIX, is sweeper in...
# 7742  Tahir to Yuvraj, out Caught by Rayudu!! Tahir ...
# 8593  Behrendorff to Kohli, FOUR, stylish shot to ge...
# 5288  Stoinis to Ishan Kishan, SIX, helps it away fo...
#
#                          batsman score  \
# 1851           Maxwell to Dhawan  FOUR
# 2089  McClenaghan to de Villiers   SIX
# 7742             Tahir to Yuvraj   OUT
# 8593        Behrendorff to Kohli  FOUR
# 5288     Stoinis to Ishan Kishan   SIX
#
#                                          Commentary_new Team_new           P1  \
# 1851  {{BATSMAN}} to {{BOWLER}}, FOUR, poor line fro...      SRH      Maxwell
# 2089  {{BATSMAN}} to {{BOWLER}}, SIX, is sweeper in ...      RCB  McClenaghan
# 7742  {{BATSMAN}} to {{BOWLER}}, out Caught by Rayud...       MI        Tahir
# 8593  {{BATSMAN}} to {{BOWLER}}, FOUR, stylish shot ...      RCB  Behrendorff
# 5288  {{BATSMAN}} to {{BOWLER}}, SIX, helps it away ...       MI      Stoinis
#
#                 P2        P1_FN P1_LN   P2_FN     P2_LN  P1_FN_count  \
# 1851        Dhawan      Maxwell  None  Dhawan      None            7
# 2089   de Villiers  McClenaghan  None      de  Villiers           11
# 7742        Yuvraj        Tahir  None  Yuvraj      None            5
# 8593         Kohli  Behrendorff  None   Kohli      None           11
# 5288  Ishan Kishan      Stoinis  None   Ishan    Kishan            7
#
#       P1_LN_count  P2_FN_count  P2_LN_count
# 1851          NaN            6          NaN
# 2089          NaN            2          8.0
# 7742          NaN            6          NaN
# 8593          NaN            5          NaN
# 5288          NaN            5          6.0
