# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_url = '/content/drive/My Drive/Colab Notebooks/AT2B/commentary.csv'
df = pd.read_csv(file_url)

# %%
df_cleaned = df.copy()

# %%
df_cleaned['Commentary_new'] = np.nan
df_cleaned['Team_new'] = df_cleaned['Team'].str.split(' ').str[0]
df_cleaned[['P1', 'P2']] = df_cleaned.batsman.str.split(" to ", expand = True)
df_cleaned[['P1_FN', 'P1_LN']] = df_cleaned['P1'].str.split(" ", 1, expand = True)
df_cleaned[['P2_FN', 'P2_LN']] = df_cleaned['P2'].str.split(" ", 1, expand = True)
# Out:
# <ipython-input-67-f624131bb37e>:4: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df_cleaned[['P1_FN', 'P1_LN']] = df_cleaned['P1'].str.split(" ", 1, expand = True)
# <ipython-input-67-f624131bb37e>:5: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df_cleaned[['P2_FN', 'P2_LN']] = df_cleaned['P2'].str.split(" ", 1, expand = True)

# %%
df_cleaned.sample(5)
# Out:
#       Match_id          Team  Over_num  \
# 550    5054401  SRH 1st Inns      13.1
# 4159   6071727  KKR 1st Inns       8.4
# 9487   8556160  RCB 1st Inns       2.1
# 494    2172197   DC 1st Inns       5.4
# 2426   4825658  SRH 1st Inns       4.2
#
#                                              Commentary  \
# 550   Harbhajan to Deepak Hooda, out Caught by Polla...
# 4159  Shreyas Gopal to Narine, out Narine Run Out!! ...
# 9487  Lamichhane to Parthiv Patel, FOUR, Lamichhane ...
# 494   Chahar to Billings, FOUR, poor delivery this a...
# 2426  Stokes to Williamson, FOUR, edged and four, a ...
#
#                           batsman score  Commentary_new Team_new  \
# 550     Harbhajan to Deepak Hooda   OUT             NaN      SRH
# 4159      Shreyas Gopal to Narine   OUT             NaN      KKR
# 9487  Lamichhane to Parthiv Patel  FOUR             NaN      RCB
# 494            Chahar to Billings  FOUR             NaN       DC
# 2426         Stokes to Williamson  FOUR             NaN      SRH
#
#                  P1             P2       P1_FN  P1_LN       P2_FN  P2_LN
# 550       Harbhajan   Deepak Hooda   Harbhajan   None      Deepak  Hooda
# 4159  Shreyas Gopal         Narine     Shreyas  Gopal      Narine   None
# 9487     Lamichhane  Parthiv Patel  Lamichhane   None     Parthiv  Patel
# 494          Chahar       Billings      Chahar   None    Billings   None
# 2426         Stokes     Williamson      Stokes   None  Williamson   None

# %%
for ind in df_cleaned.index:
  df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary'][ind].replace(df_cleaned['P1'][ind], '{{BATSMAN}}')
  df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary_new'][ind].replace(df_cleaned['P1_FN'][ind], '{{BATSMAN}}')
  if (df_cleaned['P1_LN'][ind] != None) :
    df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary_new'][ind].replace(df_cleaned['P1_LN'][ind], '{{BATSMAN}}')
  df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary_new'][ind].replace(df_cleaned['P2'][ind], '{{BOWLER}}')
  df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary_new'][ind].replace(df_cleaned['P2_FN'][ind], '{{BOWLER}}')
  if (df_cleaned['P2_LN'][ind] != None) :
    df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary_new'][ind].replace(df_cleaned['P2_LN'][ind], '{{BOWLER}}')
  df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary_new'][ind].replace(df_cleaned['Team_new'][ind], '{{TEAM}}')
# Out:
# <ipython-input-69-ca2b51d8a024>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary'][ind].replace(df_cleaned['P1'][ind], '{{BATSMAN}}')

# %%
df_cleaned.sample(5)
# Out:
#       Match_id          Team  Over_num  \
# 2929   3320338   GL 1st Inns       2.3
# 280    7088566  RCB 1st Inns      12.3
# 8095   4297600  SRH 1st Inns      20.0
# 6634   8593147  SRH 1st Inns      11.5
# 241    2837493  RPS 1st Inns       3.2
#
#                                              Commentary  \
# 2929  S Kaul to Ishan Kishan, SIX, "he is a puller" ...
# 280   Mishra to Kedar Jadhav, FOUR, pushed through f...
# 8095  Shami to Hooda, SIX, 1 off the first 3 balls a...
# 6634  Jadeja to Brathwaite, no run, run-out chance m...
# 241   Mohit Sharma to Rahane, 1 run, DROPPED!! The m...
#
#                      batsman   score  \
# 2929  S Kaul to Ishan Kishan     SIX
# 280   Mishra to Kedar Jadhav    FOUR
# 8095          Shami to Hooda     SIX
# 6634    Jadeja to Brathwaite  NO RUN
# 241   Mohit Sharma to Rahane     ONE
#
#                                          Commentary_new Team_new  \
# 2929  {{BAT{{BATSMAN}}MAN}} to {{BOWLER}}, {{BATSMAN...       GL
# 280   {{BATSMAN}} to {{BOWLER}}, FOUR, pushed throug...      RCB
# 8095  {{BATSMAN}} to {{BOWLER}}, SIX, 1 off the firs...      SRH
# 6634  {{BATSMAN}} to {{BOWLER}}, no run, run-out cha...      SRH
# 241   {{BATSMAN}} to {{BOWLER}}, 1 run, DROPPED!! Th...      RPS
#
#                 P1            P2   P1_FN   P1_LN       P2_FN   P2_LN
# 2929        S Kaul  Ishan Kishan       S    Kaul       Ishan  Kishan
# 280         Mishra  Kedar Jadhav  Mishra    None       Kedar  Jadhav
# 8095         Shami         Hooda   Shami    None       Hooda    None
# 6634        Jadeja    Brathwaite  Jadeja    None  Brathwaite    None
# 241   Mohit Sharma        Rahane   Mohit  Sharma      Rahane    None
