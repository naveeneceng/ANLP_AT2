# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_url = '/content/drive/My Drive/Colab Notebooks/AT2B/commentary.csv'
df = pd.read_csv(file_url)

# %%
df_cleaned = df.copy()

# %%
df_cleaned['Commentary_new'] = np.nan
df_cleaned['Team_new'] = df_cleaned['Team'].str.split(' ').str[0]

# %%
df_cleaned[['P1', 'P2']] = df_cleaned.batsman.str.split(" to ", expand = True)

# %%
df_cleaned.head()
# Out:
#    Match_id          Team  Over_num  \
# 0   4281444  RCB 1st Inns       0.5
# 1   4281444  RCB 1st Inns       1.0
# 2   4281444  RCB 1st Inns      10.0
# 3   4281444  RCB 1st Inns      10.4
# 4   4281444  RCB 1st Inns      10.5
#
#                                           Commentary  \
# 0  Nehra to Mandeep, FOUR, first boundary for Man...
# 1  Nehra to Mandeep, FOUR, back-to-back boundarie...
# 2  Henriques to Kedar Jadhav, FOUR, hit straight ...
# 3  Nehra to Kedar Jadhav, FOUR, another full toss...
# 4  Nehra to Kedar Jadhav, FOUR, four more. Jadhav...
#
#                      batsman score  Commentary_new Team_new         P1  \
# 0           Nehra to Mandeep  FOUR             NaN      RCB      Nehra
# 1           Nehra to Mandeep  FOUR             NaN      RCB      Nehra
# 2  Henriques to Kedar Jadhav  FOUR             NaN      RCB  Henriques
# 3      Nehra to Kedar Jadhav  FOUR             NaN      RCB      Nehra
# 4      Nehra to Kedar Jadhav  FOUR             NaN      RCB      Nehra
#
#              P2
# 0       Mandeep
# 1       Mandeep
# 2  Kedar Jadhav
# 3  Kedar Jadhav
# 4  Kedar Jadhav

# %%
for ind in df_cleaned.index:
  df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary'][ind].replace(df_cleaned['P1'][ind], '{{BATSMAN}}')
  df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary_new'][ind].replace(df_cleaned['P2'][ind], '{{BOWLER}}')
  df_cleaned['Commentary_new'][ind] = df_cleaned['Commentary_new'][ind].replace(df_cleaned['Team_new'][ind], '{{TEAM}}')

# %%
df_cleaned.head()
# Out:
#    Match_id          Team  Over_num  \
# 0   4281444  RCB 1st Inns       0.5
# 1   4281444  RCB 1st Inns       1.0
# 2   4281444  RCB 1st Inns      10.0
# 3   4281444  RCB 1st Inns      10.4
# 4   4281444  RCB 1st Inns      10.5
#
#                                           Commentary  \
# 0  Nehra to Mandeep, FOUR, first boundary for Man...
# 1  Nehra to Mandeep, FOUR, back-to-back boundarie...
# 2  Henriques to Kedar Jadhav, FOUR, hit straight ...
# 3  Nehra to Kedar Jadhav, FOUR, another full toss...
# 4  Nehra to Kedar Jadhav, FOUR, four more. Jadhav...
#
#                      batsman score  \
# 0           Nehra to Mandeep  FOUR
# 1           Nehra to Mandeep  FOUR
# 2  Henriques to Kedar Jadhav  FOUR
# 3      Nehra to Kedar Jadhav  FOUR
# 4      Nehra to Kedar Jadhav  FOUR
#
#                                       Commentary_new Team_new         P1  \
# 0  {{BATSMAN}} to {{BOWLER}}, FOUR, first boundar...      RCB      Nehra
# 1  {{BATSMAN}} to {{BOWLER}}, FOUR, back-to-back ...      RCB      Nehra
# 2  {{BATSMAN}} to {{BOWLER}}, FOUR, hit straight ...      RCB  Henriques
# 3  {{BATSMAN}} to {{BOWLER}}, FOUR, another full ...      RCB      Nehra
# 4  {{BATSMAN}} to {{BOWLER}}, FOUR, four more. Ja...      RCB      Nehra
#
#              P2
# 0       Mandeep
# 1       Mandeep
# 2  Kedar Jadhav
# 3  Kedar Jadhav
# 4  Kedar Jadhav
